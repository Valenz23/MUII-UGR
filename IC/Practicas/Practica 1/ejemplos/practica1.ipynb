# %%
from keras.datasets import mnist        # conjunto con imagenes de numeros del 0 al 9

(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# WARNING:tensorflow:From c:\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ...
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
from matplotlib import pyplot as plt
from itertools import product
import numpy as np

nrows = 5
ncols = 5

fig, ax = plt.subplots(nrows, ncols, figsize=(5,5))

np.random.seed(12345) # controlamos la semilla para obtener siempre los mismos resultados

for i, j in product(range(nrows), range(ncols)):
    ax[i, j].imshow(train_X[np.random.randint(0, train_X.shape[0]) ], cmap=plt.get_cmap('gray'))
    ax[i, j].imshow(train_X[np.random.randint(0, train_X.shape[0]) ], cmap=plt.get_cmap('gray'))


plt.show()

# %%
from sklearn.linear_model import Perceptron

x_train = train_X.astype("float64")/255.0
x_train = x_train.reshape((60000, (28*28)))

x_test = test_X.astype("float64")/255.0
x_test = x_test.reshape((10000, (28*28)))


p = Perceptron(random_state=32, max_iter=50, tol=0.0001)

p.fit(X=x_train, y=train_y)

error_rate = (1 - p.score(X=x_test, y=test_y)) * 100

print(error_rate)
# Out:
# 12.660000000000004

# %%
from sklearn.neural_network import MLPClassifier


mlc = MLPClassifier(
    random_state=123,
    hidden_layer_sizes=(800,400),
    verbose=True
)

mlc.fit(X=x_train, y=train_y)

print(1 - p.score(X=x_test, y=test_y)/100)
# Out:
# Iteration 1, loss = 0.22674563
# Iteration 2, loss = 0.08136068
# Iteration 3, loss = 0.04926387
# Iteration 4, loss = 0.03477953
# Iteration 5, loss = 0.02648958
# Iteration 6, loss = 0.01909944
# Iteration 7, loss = 0.01443020
# Iteration 8, loss = 0.01353902
# Iteration 9, loss = 0.01604022
# Iteration 10, loss = 0.01214198
# Iteration 11, loss = 0.01202146
# Iteration 12, loss = 0.00768777
# Iteration 13, loss = 0.01093305
# Iteration 14, loss = 0.01010675
# Iteration 15, loss = 0.00777434
# Iteration 16, loss = 0.01410957
# Iteration 17, loss = 0.00667998
# Iteration 18, loss = 0.00858295
# 0.991266
# c:\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
